# %% [markdown]
# creacion de movimientos del punto en las diferentes escenas

# %% [markdown]
# se crea el modelo en donde se manejara las diferentes escena

# %%
import matplotlib.pyplot as plt
import numpy as np

class escena:
    def __init__(self, ancho, alto):
        self.ancho = ancho
        self.alto = alto

    def graficar(self):
              # Crear una figura y un eje para la gráfica
        fig, ax = plt.subplots()



        # Vértices del rectángulo como puntos en forma de vectores
        p0 = np.array([0, 0])  # Punto inferior izquierdo
        p1 = np.array([self.ancho, 0])  # Punto inferior derecho
        p2 = np.array([self.ancho, self.alto])  # Punto superior derecho
        p3 = np.array([0, self.alto])  # Punto superior izquierdo

        # Vectores que definen los lados del rectángulo
        v0 = p1 - p0  # Vector de desplazamiento desde p0 a p1
        v1 = p2 - p1  # Vector de desplazamiento desde p1 a p2
        v2 = p3 - p2  # Vector de desplazamiento desde p2 a p3
        v3 = p0 - p3  # Vector de desplazamiento desde p3 a p0

        # Graficar el rectángulo usando los vectores
        ax.quiver(p0[0], p0[1], v0[0], v0[1], angles='xy', scale_units='xy', scale=1,)  # Lado inferior
        ax.quiver(p1[0], p1[1], v1[0], v1[1], angles='xy', scale_units='xy', scale=1, )  # Lado derecho
        ax.quiver(p2[0], p2[1], v2[0], v2[1], angles='xy', scale_units='xy', scale=1, )  # Lado superior
        ax.quiver(p3[0], p3[1], v3[0], v3[1], angles='xy', scale_units='xy', scale=1, )  # Lado izquierdo



        ax.scatter(x=[10], y=[5], color='red')  # posicion del punto

        # Configuración para que la visualización sea más clara
        ax.set_aspect('equal', adjustable='box')
        ax.set_xlim(-5, self.ancho + 5)  # Límite en x
        ax.set_ylim(-5, self.alto + 5)  # Límite en y
        plt.grid(True)  # Mostrar la cuadrícula
        plt.title(" escena")
        plt.show()

# Crear un rectángulo
rectangulo = escena(20, 10)
rectangulo.graficar()

# %% [markdown]
# creacion de la funcion crear_escena

# %%
import matplotlib.pyplot as plt
import numpy as np

class escena:
    def __init__(self, ancho, alto):
        self.ancho = ancho
        self.alto = alto



    def crear_escena(self):


        # Crear una figura y un eje para la gráfica
        fig, ax = plt.subplots()

        # color del rectángulo
        color_rentangulo = ('azure')

        # Vértices del rectángulo como puntos en forma de vectores
        p0 = np.array([2, 2])  # Punto inferior izquierdo
        p1 = np.array([self.ancho, 2])  # Punto inferior derecho
        p2 = np.array([self.ancho, self.alto])  # Punto superior derecho
        p3 = np.array([2, self.alto])  # Punto superior izquierdo

        # Vectores que definen los lados del rectángulo
        v0 = p1 - p0  # Vector de desplazamiento desde p0 a p1 (lado inferior)
        v1 = p2 - p1  # Vector de desplazamiento desde p1 a p2 (lado derecho)
        v2 = p3 - p2  # Vector de desplazamiento desde p2 a p3 (lado superior)
        v3 = p0 - p3  # Vector de desplazamiento desde p3 a p0 (lado izquierdo)

        # Graficar el rectángulo usando los vectores
        ax.quiver(p0[0], p0[1], v0[0], v0[1], angles='xy', scale_units='xy', scale=1, color="red") # Lado inferior
        ax.quiver(p1[0], p1[1], v1[0], v1[1], angles='xy', scale_units='xy', scale=1, color="gold")  # Lado derecho
        ax.quiver(p2[0], p2[1], v2[0], v2[1], angles='xy', scale_units='xy', scale=1, color="brown")  # Lado superior
        ax.quiver(p3[0], p3[1], v3[0], v3[1], angles='xy', scale_units='xy', scale=1, color="blue")  # Lado izquierdo

        # Graficar el rectángulo usando un polígono (para rellenarlo)
        ax.fill([p0[0], p1[0], p2[0], p3[0]], [p0[1], p1[1], p2[1], p3[1]], color=color_rentangulo)

        # Dibujar puntos adicionales
        ax.scatter(x=[3,5,3,8], y=[4,7,8,3], color='black')

        # Configuración para que la visualización sea más clara
        ax.set_aspect('equal', adjustable='box')  # Asegurar que el aspecto sea igual para x y y
        ax.set_xlim(0, self.ancho + 1)  # Límite en x
        ax.set_ylim(0, self.alto + 1)  # Límite en y
        plt.grid(True)  # Mostrar la cuadrícula
        plt.title("creacion de escena")
        plt.show()

# Crear un rectángulo
rectangulo = escena(10, 10)

rectangulo.crear_escena()

# %% [markdown]
# creacion de la funcion cambiar escena
# **texto en negrita**

# %%
import matplotlib.pyplot as plt
import numpy as np

class escena:
    def __init__(self, ancho, alto):
        self.ancho = ancho
        self.alto = alto



    def cambiar_escena(self):


        # Crear una figura y un eje para la gráfica
        fig, ax = plt.subplots()

        # color del rectángulo
        color_rentangulo = ('#F08080')


        # Vértices del rectángulo como puntos en forma de vectores
        p0 = np.array([3, 0])  # Punto inferior izquierdo
        p1 = np.array([self.ancho, 0])  # Punto inferior derecho
        p2 = np.array([self.ancho, self.alto])  # Punto superior derecho
        p3 = np.array([3, self.alto])  # Punto superior izquierdo

        # Vectores que definen los lados del rectángulo
        v0 = p1 - p0  # Vector de desplazamiento desde p0 a p1 (lado inferior)
        v1 = p2 - p1  # Vector de desplazamiento desde p1 a p2 (lado derecho)
        v2 = p3 - p2  # Vector de desplazamiento desde p2 a p3 (lado superior)
        v3 = p0 - p3  # Vector de desplazamiento desde p3 a p0 (lado izquierdo)



        # Graficar el rectángulo usando los vectores
        ax.quiver(p0[0], p0[1], v0[0], v0[1], angles='xy', scale_units='xy', scale=1, color="red") # Lado inferior
        ax.quiver(p1[0], p1[1], v1[0], v1[1], angles='xy', scale_units='xy', scale=1, color="gold")  # Lado derecho
        ax.quiver(p2[0], p2[1], v2[0], v2[1], angles='xy', scale_units='xy', scale=1, color="brown")  # Lado superior
        ax.quiver(p3[0], p3[1], v3[0], v3[1], angles='xy', scale_units='xy', scale=1, color="blue")  # Lado izquierdo

        # Graficar el rectángulo usando un polígono (para rellenarlo)
        ax.fill([p0[0], p1[0], p2[0], p3[0]], [p0[1], p1[1], p2[1], p3[1]], color=color_rentangulo)

        # Dibujar puntos adicionales
        ax.scatter(x=[6,15,3,8,4,5], y=[4,7,10,3,5,10], color='#00FF00')




        # Configuración para que la visualización sea más clara
        ax.set_aspect('equal', adjustable='box')  # Asegurar que el aspecto sea igual para x y y
        ax.set_xlim(0, self.ancho + 1)  # Límite en x
        ax.set_ylim(0, self.alto + 1)  # Límite en y
        plt.grid(True)  # Mostrar la cuadrícula
        plt.title("cambiar escena")
        plt.show()

# Crear un rectángulo
rectangulo = escena(30, 10)

rectangulo.cambiar_escena()

# %% [markdown]
# creacion de la funcion dibujar escena

# %%
import matplotlib.pyplot as plt
import numpy as np

class escena:
    def __init__(self,ancho=10, alto=10, punto=(5, 5), radio=0.5):
        self.ancho = ancho
        self.alto = alto
        # El punto estará definido por coordenadas (x, y)
        self.punto = punto
        # Radio del círculo que representa el punto
        self.radio = radio

    def dibujar_escena(self):
              # Crear una figura y un eje para la gráfica
        fig, ax = plt.subplots()



        # Vértices del rectángulo como puntos en forma de vectores
        p0 = np.array([0, 0])  # Punto inferior izquierdo
        p1 = np.array([self.ancho, 0])  # Punto inferior derecho
        p2 = np.array([self.ancho, self.alto])  # Punto superior derecho
        p3 = np.array([0, self.alto])  # Punto superior izquierdo

        # Vectores que definen los lados del rectángulo
        v0 = p1 - p0  # Vector de desplazamiento desde p0 a p1
        v1 = p2 - p1  # Vector de desplazamiento desde p1 a p2
        v2 = p3 - p2  # Vector de desplazamiento desde p2 a p3
        v3 = p0 - p3  # Vector de desplazamiento desde p3 a p0

        # Graficar el rectángulo usando los vectores
        ax.quiver(p0[0], p0[1], v0[0], v0[1], angles='xy', scale_units='xy', scale=1,)
        ax.quiver(p1[0], p1[1], v1[0], v1[1], angles='xy', scale_units='xy', scale=1, )
        ax.quiver(p2[0], p2[1], v2[0], v2[1], angles='xy', scale_units='xy', scale=1, )
        ax.quiver(p3[0], p3[1], v3[0], v3[1], angles='xy', scale_units='xy', scale=1, )

        # Crear un círculo en las coordenadas del punto
        circulo = patches.Circle(self.punto, self.radio, color='red')
        ax.add_patch(circulo)



        ax.scatter(x=[5], y=[5], color='blue')  # posicion del punto

        # Configuración para que la visualización sea más clara
        ax.set_aspect('equal', adjustable='box')
        ax.set_xlim(-5, self.ancho + 5)  # Límite en x
        ax.set_ylim(-5, self.alto + 5)  # Límite en y
        plt.grid(True)  # Mostrar la cuadrícula
        plt.title("dibujar escena")
        plt.show()

# Crear una escena con un rectángulo de tamaño 10x10
escena = escena(ancho=10, alto=10, punto=(5, 5), radio=3)

# Llamar al método para dibujar la escena
escena.dibujar_escena()

# %% [markdown]
# creacion de funcion crear desplazar puntos

# %%
import pygame
import sys
import numpy as np  # Importamos numpy para trabajar con vectores

pygame.init()

class Escena:
    def __init__(self, ancho, alto):
        self.ancho = ancho
        self.alto = alto
        self.posicion = np.array([ancho // 2, alto // 2])
        self.radio = 20
        self.color = (255, 0, 0)
        self.ventana = pygame.display.set_mode((ancho, alto))
        self.reloj = pygame.time.Clock()

    def desplazar_punto(self, direccion):

        movimiento = np.array([0, 0])

        if direccion == "izquierda":
            movimiento = np.array([-self.radio, 0])
        elif direccion == "derecha":
            movimiento = np.array([self.radio, 0])
        elif direccion == "arriba":
            movimiento = np.array([0, -self.radio])
        elif direccion == "abajo":
            movimiento = np.array([0, self.radio])

        # Verificamos que no se salga de los límites
        if 0 <= self.posicion[0] + movimiento[0] <= self.ancho - self.radio:
            self.posicion[0] += movimiento[0]

        if 0 <= self.posicion[1] + movimiento[1] <= self.alto - self.radio:
            self.posicion[1] += movimiento[1]

    def actualizar(self):

        self.ventana.fill((0, 0, 255))  # Rellenar con color azul
        pygame.draw.circle(self.ventana, (0, 255, 0), self.posicion, self.radio)
        pygame.display.flip()

    def manejar_eventos(self):

        for evento in pygame.event.get():
            if evento.type == pygame.QUIT:
                return False
            elif evento.type == pygame.KEYDOWN:
                if evento.key == pygame.K_LEFT:
                    self.desplazar_punto("izquierda")
                elif evento.key == pygame.K_RIGHT:
                    self.desplazar_punto("derecha")
                elif evento.key == pygame.K_UP:
                    self.desplazar_punto("arriba")
                elif evento.key == pygame.K_DOWN:
                    self.desplazar_punto("abajo")
        return True

def main():
    escena = Escena(640, 480)
    jugando = True

    while jugando:
        jugando = escena.manejar_eventos()
        escena.actualizar()
        escena.reloj.tick(60)

    pygame.quit()
    sys.exit()

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-dd502a641347> in <cell line: 0>()
#      70
#      71 if __name__ == "__main__":
# ---> 72     main()
#      73
#
# <ipython-input-57-dd502a641347> in main()
#      63     while jugando:
#      64         jugando = escena.manejar_eventos()
# ---> 65         escena.actualizar()
#      66         escena.reloj.tick(60)
#      67
#
# <ipython-input-57-dd502a641347> in actualizar(self)
#      39         self.ventana.fill((0, 0, 255))  # Rellenar con color azul
#      40         pygame.draw.circle(self.ventana, (0, 255, 0), self.posicion, self.radio)
# ---> 41         pygame.display.flip()
#      42
#      43     def manejar_eventos(self):
#
# KeyboardInterrupt:

# %% [markdown]
# creacion de la funcion similar

# %%
import pygame
import sys
import random
import numpy as np  # Importamos numpy para manejar vectores

pygame.init()

class Escena:
    def __init__(self, ancho, alto, radio=20):
        self.ancho = ancho
        self.alto = alto
        self.radio = radio
        self.lista_coord = []
        self.color = (255, 0, 0)
        self.ventana = pygame.display.set_mode((ancho, alto))
        self.reloj = pygame.time.Clock()

        # Inicializamos las coordenadas de los círculos
        for _ in range(1):
            x = random.randint(0, ancho)
            y = random.randint(0, alto)
            self.lista_coord.append(np.array([x, y]))  # Usamos numpy array como vector

    def similar(self):

        for coord in self.lista_coord:
            # Extraemos las coordenadas del vector
            x, y = coord

            # Desplazamos el círculo hacia abajo (en el eje Y)
            coord[1] += self.radio

            # Si el círculo se sale de la pantalla, lo reiniciamos en la parte superior
            if coord[1] > self.alto:
                coord[1] = 0


    def dibujar(self):

        self.ventana.fill((0, 0, 255))  # Rellenar con color azul

        for coord in self.lista_coord:
            x, y = coord
            pygame.draw.circle(self.ventana, self.color, (x, y), self.radio)

        pygame.display.flip()

    def manejar_eventos(self):

        for evento in pygame.event.get():
            if evento.type == pygame.QUIT:
                return False
        return True

    def actualizar(self):

        self.similar()  # Mover los círculos
        self.dibujar()  # Dibujar la escena

def main():
    escena = Escena(300, 300)
    jugando = True

    while jugando:
        jugando = escena.manejar_eventos()
        escena.actualizar()
        escena.reloj.tick(5)  # Controla la velocidad de actualización

    pygame.quit()
    sys.exit()

if __name__ == "__main__":
    main()

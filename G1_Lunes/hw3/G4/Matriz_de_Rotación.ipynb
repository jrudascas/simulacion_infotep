# %% [markdown]
# # **Matrices de rotación simples en un espacio tridimensional**

# %% [markdown]
# **Docente:** Jorge Rudas
#
# **Diseño de prototipos - 2025 I**
#
# **INFOTEP**

# %%
import numpy as np
from sympy import*
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
init_printing()

# %% [markdown]
# # **Función dibujar un vector punto en un espacio tridimencional**

# %%
def dibujar_punto(punto, label, x_lim = [0, 1], y_lim=[0, 1], z_lim=[0, 1]):
  """
  Dibuja un punto en un espacio tridimensional.

  Parametros:
    punto: Un vector NumPy de tres elementos representando las coordenadas (x, y, z) del punto.
    label: Una cadena de texto para etiquetar el punto en el gráfico.
    x_lim: Una lista de dos elementos que define los límites del eje x.
    y_lim: Una lista de dos elementos que define los límites del eje y.
    z_lim: Una lista de dos elementos que define los límites del eje z.
  """

  fig = plt.figure()
  ax = fig.add_subplot(111, projection='3d')

  ax.scatter(punto[0], punto[1], punto[2], color='b', label=label)

  ax.set_xlabel('X')
  ax.set_ylabel('Y')
  ax.set_zlabel('Z')
  ax.set_title('Espacio 3D')

  ax.quiver(0, 0, 0, punto[0], punto[1], punto[2], color='b')

  ax.set_xlim(x_lim)
  ax.set_ylim(y_lim)
  ax.set_zlim(z_lim)
  ax.legend()
  plt.show()

# %%
## Angulo simbolico
theta = symbols("theta",  real=True)

# %% [markdown]
# ### **Rotación en el eje x**

# %%
## Matrix de rotación simbolica sobre le eje X
R_x = Matrix([[1, 0, 0], [0, cos(theta), -sin(theta)], [0, sin(theta), cos(theta)]])
R_x

# %% [markdown]
# ## Definicion de un punto de prueba en el espacio tridimensional

# %%
P0 = np.array([1, 1, 0])
print(P0)
# Out:
# [1 1 0]

# %%
dibujar_punto(P0, "Punto P0", y_lim=[-1,1])

# %% [markdown]
# ### **Aplicación de la matrix de rotación**

# %%
theta_val = np.pi #180 grados en radianes
R_p0 = np.array(R_x.subs({theta: theta_val})).astype(np.float64) #Se convierte theta simbolico a un valor concreto

P0_rotado = np.dot(R_p0, P0) #Producto punto entre la matrix de rotación y el vector de posición del punto
print(P0_rotado)
# Out:
# [ 1.0000000e+00 -1.0000000e+00  1.2246468e-16]

# %%
dibujar_punto(P0_rotado, "Punto P0 rotado", y_lim=[-1, 1])

# %% [markdown]
# ### **Aplicación de la matrix de rotación**

# %%
theta_val = np.pi/4 # 45 grados en radianes
R_p0 = np.array(R_x.subs({theta: theta_val})).astype(np.float64) #Se convierte theta simbolico a un valor concreto

P0_rotado = np.dot(R_p0, P0) #Producto punto entre la matrix de rotación y el vector de posición del punto
print(P0_rotado)
# Out:
# [1.         0.70710678 0.70710678]

# %%
dibujar_punto(P0_rotado, "Punto P0 rotado", y_lim=[0, 1])

# %% [markdown]
# ### **Rotación en el eje y**

# %%
R_y = Matrix([[cos(theta), 0, sin(theta)], [0, 1, 0], [-sin(theta), 0, cos(theta)]])
R_y
# Out:
# ⎡cos(θ)   0  sin(θ)⎤
# ⎢                  ⎥
# ⎢   0     1    0   ⎥
# ⎢                  ⎥
# ⎣-sin(θ)  0  cos(θ)⎦

# %% [markdown]
# ### **Rotación en el eje z**

# %%
R_z = Matrix([[cos(theta), -sin(theta), 0], [sin(theta), cos(theta), 0], [0, 0, 1]])
R_z
# Out:
# ⎡cos(θ)  -sin(θ)  0⎤
# ⎢                  ⎥
# ⎢sin(θ)  cos(θ)   0⎥
# ⎢                  ⎥
# ⎣  0        0     1⎦

# %% [markdown]
# ### **Ilustración angulos de rotación**

# %%
from IPython.display import Image


Image(url='https://www.researchgate.net/publication/348803228/figure/fig7/AS:984434408955905@1611718861641/a-Pitch-yaw-and-roll-angles-of-an-aircraft-with-body-orientation-O-u-v-original.ppm')
# Out:
# <img src="https://www.researchgate.net/publication/348803228/figure/fig7/AS:984434408955905@1611718861641/a-Pitch-yaw-and-roll-angles-of-an-aircraft-with-body-orientation-O-u-v-original.ppm"/>

# %% [markdown]
# ### **Multiples rotaciones**

# %%
dibujar_punto(P0, "P0",x_lim=[-1, 1], y_lim=[-1, 1])

# %%
theta_val = np.pi # 180 grados en radianes
R_x_p0 = np.array(R_x.subs({theta: theta_val})).astype(np.float64) #Se convierte theta simbolico a un valor concreto Rx
R_y_p0 = np.array(R_y.subs({theta: theta_val})).astype(np.float64) #Se convierte theta simbolico a un valor concreto Ry
R_z_p0 = np.array(R_z.subs({theta: theta_val})).astype(np.float64) #Se convierte theta simbolico a un valor concreto Rz

P0_rotado_x = np.dot(R_x_p0, P0) #Producto punto entre la matrix de rotación y el vector de posición del punto
P0_rotado_y = np.dot(R_y_p0, P0_rotado_x) #Producto punto entre la matrix de rotación y el vector de posición del punto
P0_rotado_z = np.dot(R_z_p0, P0_rotado_y) #Producto punto entre la matrix de rotación y el vector de posición del punto

print(P0)
print(P0_rotado_x)
print(P0_rotado_y)
print(P0_rotado_z)
# Out:
# [1 1 0]
# [ 1.0000000e+00 -1.0000000e+00  1.2246468e-16]
# [-1.0000000e+00 -1.0000000e+00 -2.4492936e-16]
# [ 1.0000000e+00  1.0000000e+00 -2.4492936e-16]

# %%
dibujar_punto(P0_rotado_x, label = 'Rotacion X', x_lim=[-1, 1], y_lim=[-1, 1])
dibujar_punto(P0_rotado_y, label = 'Rotacion Y', x_lim=[-1, 1], y_lim=[-1, 1])
dibujar_punto(P0_rotado_z, label = 'Rotacion Z', x_lim=[-1, 1], y_lim=[-1, 1])

# %% [markdown]
# # **Actividad**
#
# 1.   Evalue el efecto del orden de las rotaciones y saque sus propias conclusiones
# 2.   Agregue una función que re utilice la implementación compartida para hacer traslaciones

# %% [markdown]
# # **CODIGO REESCRITO**

# %%
import numpy as np
from sympy import*
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
init_printing()

# %% [markdown]
# ## Función dibujar un vector punto en un espacio tridimencional

# %%
def dibujar_punto(punto, label, x_lim = [0, 1], y_lim=[0, 1], z_lim=[0, 1]):
  """
  Dibuja un punto en un espacio tridimensional.

  Parametros:
    punto: Un vector NumPy de tres elementos representando las coordenadas (x, y, z) del punto.
    label: Una cadena de texto para etiquetar el punto en el gráfico.
    x_lim: Una lista de dos elementos que define los límites del eje x.
    y_lim: Una lista de dos elementos que define los límites del eje y.
    z_lim: Una lista de dos elementos que define los límites del eje z.
  """

  fig = plt.figure()
  ax = fig.add_subplot(111, projection='3d')

  ax.scatter(punto[0], punto[1], punto[2], color='b', label=label)

  ax.set_xlabel('X')
  ax.set_ylabel('Y')
  ax.set_zlabel('Z')
  ax.set_title('Espacio 3D')

  ax.quiver(0, 0, 0, punto[0], punto[1], punto[2], color='b')

  ax.set_xlim(x_lim)
  ax.set_ylim(y_lim)
  ax.set_zlim(z_lim)
  ax.legend()
  plt.show()

# %% [markdown]
# Angulo theta

# %%
 ## Angulo simbolico
theta = symbols("theta",  real=True)

# %% [markdown]
# ## Definición de un punto de prueba en el espacio tridimencional

# %%
P0 = np.array([1, 1, 0])

# %% [markdown]
# ## Rotación en los ejes x, y, z

# %%
## Matrix de rotación simbolica sobre los ejes
R_x = Matrix([[1, 0, 0], [0, cos(theta), -sin(theta)], [0, sin(theta), cos(theta)]])
R_x

R_y = Matrix([[cos(theta), 0, sin(theta)], [0, 1, 0], [-sin(theta), 0, cos(theta)]])
R_y

R_z = Matrix([[cos(theta), -sin(theta), 0], [sin(theta), cos(theta), 0], [0, 0, 1]])
R_z

# %% [markdown]
# # **MULTIPLES EJEMPLOS DE USO**

# %% [markdown]
# ## Para 180 grados con orden Y, X, Z

# %%
theta_val = np.pi # 180 grados (Se puede ajustar los grados para resultados distintos)

R_x_p0 = np.array(R_x.subs({theta: theta_val})).astype(np.float64) #Se convierte theta simbolico a un valor concreto Rx
R_y_p0 = np.array(R_y.subs({theta: theta_val})).astype(np.float64) #Se convierte theta simbolico a un valor concreto Ry
R_z_p0 = np.array(R_z.subs({theta: theta_val})).astype(np.float64) #Se convierte theta simbolico a un valor concreto Rz

P0_rotado_y = np.dot(R_y_p0, P0) #Producto punto entre la matrix de rotación y el vector de posición del punto
P0_rotado_x = np.dot(R_x_p0, P0_rotado_y) #Producto punto entre la matrix de rotación y el vector de posición del punto
P0_rotado_z = np.dot(R_z_p0, P0_rotado_x) #Producto punto entre la matrix de rotación y el vector de posición del punto

#print(P0)
print(P0_rotado_y)
print(P0_rotado_x)
print(P0_rotado_z)

# %%
dibujar_punto(P0_rotado_x, label = 'Rotacion Y', x_lim=[-1, 1], y_lim=[-1, 1])
dibujar_punto(P0_rotado_y, label = 'Rotacion X', x_lim=[-1, 1], y_lim=[-1, 1])
dibujar_punto(P0_rotado_z, label = 'Rotacion Z', x_lim=[-1, 1], y_lim=[-1, 1])

# %% [markdown]
# Se puede apreciar que desde el orden Y, X, Z el orden del vector cambia, donde es más notable en la rotación de X con respecto al orden original.

# %% [markdown]
# ## Para 180 grados con orden Z, Y, X

# %%
theta_val = np.pi # 180 grados (Se puede ajustar los grados para resultados distintos)

R_x_p0_2 = np.array(R_x.subs({theta: theta_val})).astype(np.float64) #Se convierte theta simbolico a un valor concreto Rx
R_y_p0_2 = np.array(R_y.subs({theta: theta_val})).astype(np.float64) #Se convierte theta simbolico a un valor concreto Ry
R_z_p0_2 = np.array(R_z.subs({theta: theta_val})).astype(np.float64) #Se convierte theta simbolico a un valor concreto Rz

P0_rotado_z_2 = np.dot(R_z_p0_2, P0) #Producto punto entre la matrix de rotación y el vector de posición del punto
P0_rotado_y_2 = np.dot(R_y_p0_2, P0_rotado_z_2) #Producto punto entre la matrix de rotación y el vector de posición del punto
P0_rotado_x_2 = np.dot(R_x_p0_2, P0_rotado_y_2) #Producto punto entre la matrix de rotación y el vector de posición del punto

#print(P0)
print(P0_rotado_z_2)
print(P0_rotado_y_2)
print(P0_rotado_x_2)

# %%
dibujar_punto(P0_rotado_x_2, label = 'Rotacion Z', x_lim=[-1, 1], y_lim=[-1, 1])
dibujar_punto(P0_rotado_y_2, label = 'Rotacion Y', x_lim=[-1, 1], y_lim=[-1, 1])
dibujar_punto(P0_rotado_z_2, label = 'Rotacion X', x_lim=[-1, 1], y_lim=[-1, 1])

# %% [markdown]
# Para este orden vemos más de lo mismo, el eje X y Y son los que cambian en este caso, casi que tomando las coordenadas del otro en el orden X, Y, Z

# %% [markdown]
# ## Grado totalmente aleatorio X, Y, Z

# %%
theta_val = np.pi/4 # 45 grados (Se puede ajustar los grados para resultados distintos)

R_x_p0_45 = np.array(R_x.subs({theta: theta_val})).astype(np.float64) #Se convierte theta simbolico a un valor concreto Rx
R_y_p0_45 = np.array(R_y.subs({theta: theta_val})).astype(np.float64) #Se convierte theta simbolico a un valor concreto Ry
R_z_p0_45 = np.array(R_z.subs({theta: theta_val})).astype(np.float64) #Se convierte theta simbolico a un valor concreto Rz

P0_rotado_x_45 = np.dot(R_x_p0_45, P0) #Producto punto entre la matrix de rotación y el vector de posición del punto
P0_rotado_y_45 = np.dot(R_y_p0_45, P0_rotado_x_45) #Producto punto entre la matrix de rotación y el vector de posición del punto
P0_rotado_z_45 = np.dot(R_z_p0_45, P0_rotado_y_45) #Producto punto entre la matrix de rotación y el vector de posición del punto

#print(P0)
print(P0_rotado_x_45)
print(P0_rotado_y_45)
print(P0_rotado_z_45)

# %%
dibujar_punto(P0_rotado_x_45, label = 'Rotacion X', x_lim=[-1, 1], y_lim=[-1, 1])
dibujar_punto(P0_rotado_y_45, label = 'Rotacion Y', x_lim=[-1, 1], y_lim=[-1, 1])
dibujar_punto(P0_rotado_z_45, label = 'Rotacion Z', x_lim=[-1, 1], y_lim=[-1, 1])

# %% [markdown]
# Si cambiamos el parametro del grado (en este caso 45 grados) vemos como el punto (P0) cambia.

# %% [markdown]
# ## Agregue una función que re utilice la implementación compartida para hacer traslaciones

# %%
def desplazamiento(punto, direccion):
    """
    Realiza una traslación de un punto en el espacio tridimensional.

    Parámetros:
        punto: Un array NumPy de tres elementos representando las coordenadas (x, y, z) del punto.
        desplazamiento: Un array NumPy de tres elementos representando la traslación en (dx, dy, dz).

    Retorna:
        Un nuevo array NumPy con las coordenadas del punto trasladado.
    """
    return np.array(punto) + np.array(direccion)

# %%
# Ejemplo de uso
P0 = np.array([1, 1, 0]) #Punto original del
D = np.array([2, -1, 3])  # Vector de traslación
P_desplazado = desplazamiento(P0, D)

print("Punto original:", P0)
print("Punto trasladado:", P_desplazado)

dibujar_punto(P_desplazado, "Traslación del punto", x_lim=[-1, 5], y_lim=[-2, 2], z_lim=[-1, 4])
